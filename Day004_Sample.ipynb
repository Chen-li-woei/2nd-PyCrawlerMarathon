# %% [markdown]
# # 利用 Python 存取 API
#
#
# * 了解 Server Client 的架構與溝通方法
# * 知道 HTTP Request & Response 的內容
# * 什麼是 API？如何用 Python 程式存取 API 資料

# %% [markdown]
# ## 下載檔案

# %%
import requests

r = requests.get('https://api.github.com/events')
r.text
# Out:
# '[{"id":"11771764342","type":"PushEvent","actor":{"id":1223213,"login":"knabben","display_login":"knabben","gravatar_id":"","url":"https://api.github.com/users/knabben","avatar_url":"https://avatars.githubusercontent.com/u/1223213?"},"repo":{"id":247539716,"name":"knabben/sqoop","url":"https://api.github.com/repos/knabben/sqoop"},"payload":{"push_id":4768987023,"size":1,"distinct_size":1,"ref":"refs/heads/go-mod","head":"eb8b5c21cf5d0d06dc36dc3ab257904bede9ff7e","before":"e18d0017d920b13e523b5495b76cc3d960a90980","commits":[{"sha":"eb8b5c21cf5d0d06dc36dc3ab257904bede9ff7e","author":{"email":"amim.knabben@gmail.com","name":"Amim Knabben"},"message":"Moving to go modules","distinct":true,"url":"https://api.github.com/repos/knabben/sqoop/commits/eb8b5c21cf5d0d06dc36dc3ab257904bede9ff7e"}]},"public":true,"created_at":"2020-03-16T01:24:34Z"},{"id":"11771764346","type":"CreateEvent","actor":{"id":49699333,"login":"dependabot[bot]","display_login":"dependabot","gravatar_id":"","url":"https://api.github.com/users/dependabot[bot]","avatar_url":"https://avatars.githubusercontent.com/u/49699333?"},"repo":{"id":236827305,"name":"luismvp10/news-app","url":"https://api.github.com/repos/luismvp10/news-app"},"payload":{"ref":"dependabot/npm_and_yarn/acorn-6.4.1","ref_type":"branch","master_branch":"master","description":null,"pusher_type":"user"},"public":true,"created_at":"2020-03-16T01:24:34Z"},{"id":"11771764341","type":"WatchEvent","actor":{"id":3536261,"login":"DevNvll","display_login":"DevNvll","gravatar_id":"","url":"https://api.github.com/users/DevNvll","avatar_url":"https://avatars.githubusercontent.com/u/3536261?"},"repo":{"id":246680755,"name":"DevNvll/siva","url":"https://api.github.com/repos/DevNvll/siva"},"payload":{"action":"started"},"public":true,"created_at":"2020-03-16T01:24:34Z"},{"id":"11771764337","type":"PullRequestEvent","actor":{"id":26499787,"login":"lyyx5858","display_login":"lyyx5858","gravatar_id":"","url":"https://api.github.com/users/lyyx5858","avatar_url":"https://avatars.githubusercontent.com/u/26499787?"},"repo":{"id":230047295,"name":"lyyx5858/gost","url":"https://api.github.com/repos/lyyx5858/gost"},"payload":{"action":"closed","number":1,"pull_request":{"url":"https://api.github.com/repos/lyyx5858/gost/pulls/1","id":388912738,"node_id":"MDExOlB1bGxSZXF1ZXN0Mzg4OTEyNzM4","html_url":"https://github.com/lyyx5858/gost/pull/1","diff_url":"https://github.com/lyyx5858/gost/pull/1.diff","patch_url":"https://github.com/lyyx5858/gost/pull/1.patch","issue_url":"https://api.github.com/repos/lyyx5858/gost/issues/1","number":1,"state":"closed","locked":false,"title":"sync with original ","user":{"login":"lyyx5858","id":26499787,"node_id":"MDQ6VXNlcjI2NDk5Nzg3","avatar_url":"https://avatars1.githubusercontent.com/u/26499787?v=4","gravatar_id":"","url":"https://api.github.com/users/lyyx5858","html_url":"https://github.com/lyyx5858","followers_url":"https://api.github.com/users/lyyx5858/followers","following_url":"https://api.github.com/users/lyyx5858/following{/other_user}","gists_url":"https://api.github.com/users/lyyx5858/gists{/gist_id}","starred_url":"https://api.github.com/users/lyyx5858/starred{/owner}{/repo}","subscriptions_url":"https://api.github.com/users/lyyx5858/subscriptions","organizations_url":"https://api.github.com/users/lyyx5858/orgs","repos_url":"https://api.github.com/users/lyyx5858/repos","events_url":"https://api.github.com/users/lyyx5858/events{/privacy}","received_events_url":"https://api.github.com/users/lyyx5858/received_events","type":"User","site_admin":false},"body":"","created_at":"2020-03-16T01:24:24Z","updated_at":"2020-03-16T01:24:34Z","closed_at":"2020-03-16T01:24:34Z","merged_at":"2020-03-16T01:24:34Z","merge_commit_sha":"de134887424f525378c765fe4136cb212c2de378","assignee":null,"assignees":[],"requested_reviewers":[],"requested_teams":[],"labels":[],"milestone":null,"draft":false,"commits_url":"https://api.github.com/repos/lyyx5858/gost/pulls/1/commits","review_comments_url":"https://ap ...

# %%
import json

json.loads(r.text)
# Out:
# {'args': {},
#  'data': '',
#  'files': {},
#  'form': {'key': 'value'},
#  'headers': {'Accept': '*/*',
#   'Accept-Encoding': 'gzip, deflate',
#   'Content-Length': '9',
#   'Content-Type': 'application/x-www-form-urlencoded',
#   'Host': 'httpbin.org',
#   'User-Agent': 'python-requests/2.22.0',
#   'X-Amzn-Trace-Id': 'Root=1-5e6ed6ed-1455df1e86f8532c59155eb6'},
#  'json': None,
#  'origin': '163.15.15.14',
#  'url': 'http://httpbin.org/post'}

# %% [markdown]
# ## 其它用法

# %%
payload = {'key1': 'value1', 'key2': 'value2'}
r = requests.get("http://httpbin.org/get", params=payload)
json.loads(r.text)
# Out:
# {'args': {'key1': 'value1', 'key2': 'value2'},
#  'headers': {'Accept': '*/*',
#   'Accept-Encoding': 'gzip, deflate',
#   'Host': 'httpbin.org',
#   'User-Agent': 'python-requests/2.22.0',
#   'X-Amzn-Trace-Id': 'Root=1-5e6ed703-02d42fe333ea588607f843f4'},
#  'origin': '163.15.15.14',
#  'url': 'http://httpbin.org/get?key1=value1&key2=value2'}

# %%
r = requests.post('http://httpbin.org/post', data = {'key':'value'})
json.loads(r.text)
# Out:
# {'args': {},
#  'data': '',
#  'files': {},
#  'form': {'key': 'value'},
#  'headers': {'Accept': '*/*',
#   'Accept-Encoding': 'gzip, deflate',
#   'Content-Length': '9',
#   'Content-Type': 'application/x-www-form-urlencoded',
#   'Host': 'httpbin.org',
#   'User-Agent': 'python-requests/2.22.0',
#   'X-Amzn-Trace-Id': 'Root=1-5e6ed706-a6ed68a45ee49882f4cc926a'},
#  'json': None,
#  'origin': '163.15.15.14',
#  'url': 'http://httpbin.org/post'}

# %%
r = requests.post('http://httpbin.org/post', data = {'key':'value'})
json.loads(r.text)
# Out:
# {'args': {},
#  'data': '',
#  'files': {},
#  'form': {'key': 'value'},
#  'headers': {'Accept': '*/*',
#   'Accept-Encoding': 'gzip, deflate',
#   'Content-Length': '9',
#   'Content-Type': 'application/x-www-form-urlencoded',
#   'Host': 'httpbin.org',
#   'User-Agent': 'python-requests/2.22.0',
#   'X-Amzn-Trace-Id': 'Root=1-5e6ed708-0895dcaa7d8b02b3ae20d167'},
#  'json': None,
#  'origin': '163.15.15.14',
#  'url': 'http://httpbin.org/post'}

# %% [markdown]
# ## 作業目標
#
# * 比較一下範例檔案中的「r.text」與「json.loads(r.text)」讀出來的內容有什麼差異
# * 自行尋找一個合適的 API 接口做練習，並且查看其回傳內容
#     * https://cat-fact.herokuapp.com/facts (來源：https://alexwohlbruck.github.io/cat-facts/)
#     * http://odata.wra.gov.tw/v4/RealtimeWaterLevel (來源：https://data.gov.tw/dataset/25768)
