# %% [markdown]
# # 反爬：瀏覽器標頭與基本資訊
#
#
# * 了解「檢查 HTTP 標頭檔」的反爬蟲機制
# * 「檢查 HTTP 標頭檔」反爬蟲的因應策略

# %% [markdown]
# ## 作業目標
#
# * 尋找一個網站是有作 Header 檢查的（Hint: 有加跟沒有加回傳結果不一樣）
# * 用上述網站說明該如何判斷 Header 中必須加上哪些資料才會正確

# %% [markdown]
# ### 尋找一個網站是有作 Header 檢查的（Hint: 有加跟沒有加回傳結果不一樣）

# %%
import requests
r = requests.get('https://www.thsrc.com.tw/index.html')
response = r.text

response
# Out:
# '\r\n<!DOCTYPE html>\r\n<html>\r\n<head>\r\n\t<!-- ç\x89\x88æ\x9c¬æ\x97¥æ\x9c\x9f:2017/08/23 -->\r\n\t<!--[if IE 6]>\r\n\t<link href="/Content/css/mainpngFix.css"  rel="stylesheet" type="text/css" />\r\n\t<script src="/Content/iepngfix/iepngfix_tilebg.js" type="text/javaScript"></script> \r\n\t<![endif]-->\r\n\t<!--[if lt IE 9]>\r\n\t<script src="https://cdnjs.cloudflare.com/ajax/libs/html5shiv/3.7.3/html5shiv.min.js"></script>\r\n\t<![endif]-->\r\n\t<!-- ä¾\x9dè\x9e¢å¹\x95å¤§å°\x8få\x88¤æ\x96·æ\x98¯å\x90¦ç\x82ºæ\x89\x8bæ©\x9f -->\r\n\t<link style="display:none" id="desktop" rel="Alternate" href="Index.html?force=1" media="only screen and (touch-enabled: 0)"/>\r\n\t<link style="display:none" id="phone" rel="alternate" href="http://m.thsrc.com.tw" media="only screen and (max-device-width: 640px)"/>\r\n\t<link style="display:none" id="tablet" rel="Alternate" href="Index.html?force=1" media="only screen and (min-device-width: 641px)"/>\r\n\t<meta name="viewport" content="width=device-width, user-scalable=no"/>\r\n\t<!-- ä¾\x9dè\x9e¢å¹\x95å¤§å°\x8få\x88¤æ\x96·æ\x98¯å\x90¦ç\x82ºæ\x89\x8bæ©\x9f end -->\r\n\t<link href="http://www.thsrc.com.tw/Content/logo.jpg" rel="image_src" type="image/jpeg">\r\n\t\r\n<meta charset="utf-8" />\r\n<link rel="shortcut icon" href="/Content/favicon/favicon.ico" />\r\n<link rel="apple-touch-icon" href="/Content/favicon/57_57.png" sizes="57x57" />\r\n<link rel="apple-touch-icon" href="/Content/favicon/72_72.png" sizes="72x72" />\r\n<link rel="apple-touch-icon" href="/Content/favicon/76_76.png" sizes="76x76" />\r\n<link rel="apple-touch-icon" href="/Content/favicon/114_114.png" sizes="114x114" />\r\n<link rel="apple-touch-icon" href="/Content/favicon/120_120.png" sizes="120x120" />\r\n<link rel="apple-touch-icon" href="/Content/favicon/144_144.png" sizes="144x144" />\r\n<link rel="apple-touch-icon" href="/Content/favicon/152_152.png" sizes="152x152" />\r\n<link rel="apple-touch-icon-precomposed" href="/Content/favicon/57_57.png" sizes="57x57" />\r\n<link rel="apple-touch-icon-precomposed" href="/Content/favicon/72_72.png" sizes="72x72" />\r\n<link rel="apple-touch-icon-precomposed" href="/Content/favicon/76_76.png" sizes="76x76" />\r\n<link rel="apple-touch-icon-precomposed" href="/Content/favicon/114_114.png" sizes="114x114" />\r\n<link rel="apple-touch-icon-precomposed" href="/Content/favicon/120_120.png" sizes="120x120" />\r\n<link rel="apple-touch-icon-precomposed" href="/Content/favicon/144_144.png" sizes="144x144" />\r\n<link rel="apple-touch-icon-precomposed" href="/Content/favicon/152_152.png" sizes="152x152" />\r\n\r\n\r\n<meta name="twitter:site" content="å\x8f°ç\x81£é«\x98é\x90µ" />\r\n<meta property="og:site_name" content="å\x8f°ç\x81£é«\x98é\x90µ" />\r\n<meta property="og:phone_number" content="02-4066-0000" />\r\n\r\n<meta itemscope itemtype="http://schema.org/WebSite" />\r\n<meta property="og:type" content="website" />\r\n<meta property="og:title" content="å\x8f°ç\x81£é«\x98é\x90µ" />\r\n<meta itemprop="og:headline" content="å\x8f°ç\x81£é«\x98é\x90µé\x80£çµ\x90å\x8f°ç\x81£å\x8d\x97å\x8c\x97ä¸»è¦\x81å\x9f\x8eå¸\x82ï¼\x8cæ\x88\x91å\x80\x91ä¸\x8då\x8fªæ\x98¯äº¤é\x80\x9aé\x81\x8bè¼¸æ¥\xadï¼\x8cæ\x9b´æ\x98¯æ\x8e¨å\x8b\x95å\x8f°ç\x81£Â\xadå\x89\x8dé\x80²ç\x9a\x84æ\x9c\x8då\x8b\x99æ¥\xadï¼\x9bæ\x88\x91å\x80\x91ä»£è¡¨ç\x9a\x84ä¸\x8då\x83\x85å\x8fªæ\x98¯é\x80\x9fåº¦ï¼\x8cè\x80\x8cæ\x98¯é\x80\x9fåº¦æ\x89\x80å¸¶ä¾\x86ç\x9a\x84ç\x8f¾ä»£ç\x94\x9fæ´»æ\x96°æ\x85\x8båº¦ï¼\x9bæ\x88\x91å\x80\x91ä»¥æ\x9b´æ\x96\x87æ\x98\x8eç\x9a\x84æ\x97\x85è¡\x8cé«\x94é©\x97ï¼\x8cæ\x88\x90ç\x82ºä½\xa0å¯¦ç\x8f¾å¤¢æ\x83³ç\x9a\x84å\x8a©å\x8a\x9bï¼\x8cå\x8f°ç\x81£é«\x98é\x90µï¼\x8cå¯¦è¸\x90å\x8f°ç\x81£æ\x96°ç\x94\x9fæ´»ã\x80\x82" />\r\n<meta name="description" content="å\x8f°ç\x81£é«\x98é\x90µé\x80£çµ\x90å\x8f°ç\x81£å\x8d\x97å\x8c\x97ä¸»è¦\x81å\x9f\x8eå¸\x82ï¼\x8cæ\x88\x91å\x80\x91ä¸\x8då\x8fªæ\x98¯äº¤é\x80\x9aé\x81\x8bè¼¸æ¥\xadï¼\x8cæ\x9b´æ\x98¯æ\x8e¨å\x8b\x95å\x8f°ç\x81£Â\xadå\x89\x8dé\x80²ç\x9a\x84æ\x9c\x8då\x8b\x99æ¥\xadï¼\x9 ...

# %% [markdown]
# ### 用上述網站說明該如何判斷 Header 中必須加上哪些資料才會正確

# %%
"""
Your Code Here
"""
# Out:
# '\nYour Code Here\n'
