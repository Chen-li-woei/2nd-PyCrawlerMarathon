# %% [markdown]
# # 反爬：驗證碼處理
#
# * 了解「驗證碼機制」的反爬蟲機制
# * 「驗證碼機制」反爬蟲的因應策略

# %% [markdown]
# ## 作業目標
#
# * 讀讀看「test」資料夾下的圖檔！
# * 像 test/test2.png 這種複雜的圖片怎麼辦？

# %% [markdown]
# ### 讀讀看「test」資料夾下的圖檔！

# %%
import requests
import pytesseract
from PIL import Image
from io import BytesIO

# %%
pytesseract.pytesseract.tesseract_cmd = 'C:\\Program Files\\Tesseract-OCR\\tesseract.exe'

img = Image.open("./data/test/test1.png")

code = pytesseract.image_to_string(img)
print(code)
# Out:
# 619121

# %% [markdown]
# ### 像 test/test2.png 這種複雜的圖片怎麼辦？

# %%
img1 = Image.open("./data/test/test2.png").convert("1")    #像素点变成黑白两种点，要么是0，要么是255。
img2 = Image.open("./data/test/test2.png").convert("L")    #像素值为[0,255]之间的某个数值。
img3 = Image.open("./data/test/test2.png").convert("P")    #像素值为[0,255]之间的某个数值，但它为调色板的索引值，其最终还是彩色图像。
img4 = Image.open("./data/test/test2.png").convert("RGBA") #图像从三通道变成了四通道，其R、G、B三个通道的数值没有变化，新增的alpha通道均为255，表示不透明。
img5 = Image.open("./data/test/test2.png").convert("RGB")  #原始 RGB圖像
print(img1.getpixel((0,0)))
img1
# Out:
# 255
# <PIL.Image.Image image mode=1 size=154x64 at 0x207AA274788>

# %%
print(img2.getpixel((0,0)))
img2
# Out:
# 162
# <PIL.Image.Image image mode=L size=154x64 at 0x207AA27A748>

# %%
print(img3.getpixel((0,0)))
img3
# Out:
# 1
# <PIL.Image.Image image mode=P size=154x64 at 0x207AA27AB48>

# %%
print(img4.getpixel((0,0)))
img4
# Out:
# (162, 162, 162, 255)
# <PIL.Image.Image image mode=RGBA size=154x64 at 0x207AA27A608>

# %%
print(img5.getpixel((0,0)))
img5
# Out:
# (162, 162, 162)
# <PIL.Image.Image image mode=RGB size=154x64 at 0x207AA27B0C8>

# %%
code1 = pytesseract.image_to_string(img1)
code2 = pytesseract.image_to_string(img2)
code3 = pytesseract.image_to_string(img3)
code4 = pytesseract.image_to_string(img4)
code5 = pytesseract.image_to_string(img5)
print(code1)    #不懂二值化為何分辨不出來??
print(code2)    #辨識錯誤
print(code3)    #辨識錯誤
print(code4)    #正確
print(code5)    #正確

#用具有RGB三值的判斷正確，用轉換後僅單值的皆辨識錯誤
# Out:
# 4413
# 4413
# 1413
# 1413
