# %% [markdown]
# # API 資料串接 - 以 Dcard API 實作範例
#
# * 了解 Dcard API 使用方式與回傳內容
# * 撰寫程式存取 API 且解析 JSON 格式資料

# %% [markdown]
# ## 作業目標
#
# * 請利用 API: https://www.dcard.tw/_api/forums/pet/posts?popular=true 回答下列問題：
#
# 1. 這個 API 一次會回傳幾筆資料？每一筆資料包含哪些欄位？一次30筆，每筆有35個欄位
# 2. 取出每一筆資料的「標題」、「貼文時間」、「留言人數」、「按讚人數」
# 3. 計算熱門/非熱門文章的「平均留言人數」與「平均按讚人數」

# %%
# 1. 這個 API 一次會回傳幾筆資料？每一筆資料包含哪些欄位？

import requests
r = requests.get('https://www.dcard.tw/_api/forums/mood/posts?popular=true')
response = r.text

import json
data = json.loads(response)
count=1
for d in data:
    print('count=%d  ' %count,end="")
    print(d['title'])
    count+=1

print(data[0].keys())
len(data[0].keys())
# Out:
# count=1  #新年快樂！研究員來拜年～感謝有你與我們一同見證好物宇宙的誕生🌏
# count=2  帶骨灰逛夜市……
# count=3  我真的被噁心到了
# count=4  我有一個護士夢
# count=5  婚禮伴奏被打槍的後續
# count=6  差了22歲的弟弟出生啦～～
# count=7  媽媽
# count=8  性騷擾經驗分享 #更
# count=9  那些侵占仔沒想到的事
# count=10  社交好累 都在營造自己有朋友的假象
# count=11  前任夜路走多遇到鬼了：）
# count=12  放過自己吧
# count=13  家中有長輩拜託請他們洗澡的時候不要鎖門
# count=14  我就想微波馬鈴薯啊！
# count=15  你這麼忙怎麼還有空___
# count=16  引發男女戰爭的事件
# count=17  臺灣人真溫暖(´；ω；｀)
# count=18  我媽喜歡把我的事情講出去
# count=19  是我害死媽媽的...
# count=20  其實很討厭被摸頭
# count=21  是我對這個世界有太多期望？
# count=22  脾氣好的人都沒底線
# count=23  這兩張照片概念也太像
# count=24  你想要的是大家同理你，現任被砲轟的快感嗎？
# count=25  請你原諒，我有病
# count=26  好想死
# 這到底是什麼人生
# count=27  不知道該怎麼開口
# count=28  想好好睡一覺
# count=29  小心台北黃X碩先生
# count=30  我的全世界都在崩潰
# dict_keys(['id', 'title', 'excerpt', 'anonymousSchool', 'anonymousDepartment', 'pinned', 'forumId', 'replyId', 'createdAt', 'updatedAt', 'commentCount', 'likeCount', 'withNickname', 'tags', 'topics', 'meta', 'forumName', 'forumAlias', 'gender', 'school', 'department', 'replyTitle', 'mediaMeta', 'reactions', 'hidden', 'customStyle', 'isSuspiciousAccount', 'layout', 'pinnedType', 'pinnedPriority', 'withImages', 'withVideos', 'media', 'reportReasonText', 'postAvatar'])

# %%
# 2. 取出每一筆資料的「標題」、「貼文時間」、「留言人數」、「按讚人數」
count=1
for d in data:
    print('count=%d  ' %count,end="")
    print(d['title'],d['createdAt'],d['commentCount'],d['likeCount'])
    count+=1
# Out:
# count=1  #新年快樂！研究員來拜年～感謝有你與我們一同見證好物宇宙的誕生🌏 2020-01-23T07:01:08.930Z 18 345
# count=2  帶骨灰逛夜市…… 2020-03-14T15:36:22.565Z 23 1885
# count=3  我真的被噁心到了 2020-03-14T19:51:09.424Z 159 521
# count=4  我有一個護士夢 2020-03-14T15:30:09.878Z 29 508
# count=5  婚禮伴奏被打槍的後續 2020-03-14T15:31:58.476Z 18 326
# count=6  差了22歲的弟弟出生啦～～ 2020-03-15T06:23:13.876Z 18 258
# count=7  媽媽 2020-03-14T17:56:11.971Z 3 68
# count=8  性騷擾經驗分享 #更 2020-03-14T19:32:18.157Z 47 43
# count=9  那些侵占仔沒想到的事 2020-03-14T17:15:13.051Z 8 41
# count=10  社交好累 都在營造自己有朋友的假象 2020-03-15T08:49:11.457Z 3 38
# count=11  前任夜路走多遇到鬼了：） 2020-03-15T10:57:14.154Z 17 29
# count=12  放過自己吧 2020-03-14T20:31:04.486Z 0 24
# count=13  家中有長輩拜託請他們洗澡的時候不要鎖門 2020-03-15T06:04:26.205Z 4 23
# count=14  我就想微波馬鈴薯啊！ 2020-03-14T21:03:18.085Z 4 22
# count=15  你這麼忙怎麼還有空___ 2020-03-14T15:23:59.280Z 2 20
# count=16  引發男女戰爭的事件 2020-03-14T15:20:26.369Z 62 19
# count=17  臺灣人真溫暖(´；ω；｀) 2020-03-15T03:06:11.104Z 0 16
# count=18  我媽喜歡把我的事情講出去 2020-03-15T18:09:38.178Z 4 15
# count=19  是我害死媽媽的... 2020-03-15T17:46:21.010Z 4 15
# count=20  其實很討厭被摸頭 2020-03-14T22:21:40.970Z 11 15
# count=21  是我對這個世界有太多期望？ 2020-03-14T16:26:33.814Z 6 15
# count=22  脾氣好的人都沒底線 2020-03-15T10:56:59.051Z 3 14
# count=23  這兩張照片概念也太像 2020-03-15T18:26:25.471Z 6 13
# count=24  你想要的是大家同理你，現任被砲轟的快感嗎？ 2020-03-14T19:22:54.067Z 47 13
# count=25  請你原諒，我有病 2020-03-14T17:41:50.610Z 2 13
# count=26  好想死
# 這到底是什麼人生 2020-03-15T02:28:33.095Z 8 11
# count=27  不知道該怎麼開口 2020-03-15T01:02:23.512Z 6 11
# count=28  想好好睡一覺 2020-03-14T17:50:42.790Z 2 11
# count=29  小心台北黃X碩先生 2020-03-14T15:57:48.916Z 5 11
# count=30  我的全世界都在崩潰 2020-03-14T15:51:44.229Z 4 11

# %%
# 3. 計算熱門/非熱門文章的「平均留言人數」與「平均按讚人數」

count=0
like_count=0
comm_count=0
for d in data:
    # print('count=%d,like_count=%d,comm_count=%d ' %(count,like_count,comm_count),end="")
    print(d['title'],d['commentCount'],d['likeCount'])
    count+=1
    like_count+=d.get('likeCount')
    comm_count+=d.get('commentCount')
    print('count=%d,like_count=%d,comm_count=%d ' %(count,like_count,comm_count))
print("熱門平均按讚次數%3.1f，熱門評論平均次數%3.1f\n\n" %(((like_count/(count)),(comm_count)/(count))))


r2 = requests.get('https://www.dcard.tw/_api/forums/mood/posts?popular=false')
response2 = r.text
data2 = json.loads(response)

count2=0
like_count2=0
comm_count2=0
for d1 in data2:
    # print('count=%d,like_count=%d,comm_count=%d ' %(count,like_count,comm_count),end="")
    print(d1['title'],d1['commentCount'],d1['likeCount'])
    count2+=1
    like_count2+=d.get('likeCount')
    comm_count2+=d.get('commentCount')
    print('count=%d,like_count=%d,comm_count=%d ' %(count2,like_count2,comm_count2))
print("非熱門平均按讚次數%3.1f，非熱門評論平均次數%3.1f" %(((like_count2/(count2)),(comm_count2)/(count2))))
# Out:
# #新年快樂！研究員來拜年～感謝有你與我們一同見證好物宇宙的誕生🌏 18 345
# count=1,like_count=345,comm_count=18
# 帶骨灰逛夜市…… 23 1885
# count=2,like_count=2230,comm_count=41
# 我真的被噁心到了 159 521
# count=3,like_count=2751,comm_count=200
# 我有一個護士夢 29 508
# count=4,like_count=3259,comm_count=229
# 婚禮伴奏被打槍的後續 18 326
# count=5,like_count=3585,comm_count=247
# 差了22歲的弟弟出生啦～～ 18 258
# count=6,like_count=3843,comm_count=265
# 媽媽 3 68
# count=7,like_count=3911,comm_count=268
# 性騷擾經驗分享 #更 47 43
# count=8,like_count=3954,comm_count=315
# 那些侵占仔沒想到的事 8 41
# count=9,like_count=3995,comm_count=323
# 社交好累 都在營造自己有朋友的假象 3 38
# count=10,like_count=4033,comm_count=326
# 前任夜路走多遇到鬼了：） 17 29
# count=11,like_count=4062,comm_count=343
# 放過自己吧 0 24
# count=12,like_count=4086,comm_count=343
# 家中有長輩拜託請他們洗澡的時候不要鎖門 4 23
# count=13,like_count=4109,comm_count=347
# 我就想微波馬鈴薯啊！ 4 22
# count=14,like_count=4131,comm_count=351
# 你這麼忙怎麼還有空___ 2 20
# count=15,like_count=4151,comm_count=353
# 引發男女戰爭的事件 62 19
# count=16,like_count=4170,comm_count=415
# 臺灣人真溫暖(´；ω；｀) 0 16
# count=17,like_count=4186,comm_count=415
# 我媽喜歡把我的事情講出去 4 15
# count=18,like_count=4201,comm_count=419
# 是我害死媽媽的... 4 15
# count=19,like_count=4216,comm_count=423
# 其實很討厭被摸頭 11 15
# count=20,like_count=4231,comm_count=434
# 是我對這個世界有太多期望？ 6 15
# count=21,like_count=4246,comm_count=440
# 脾氣好的人都沒底線 3 14
# count=22,like_count=4260,comm_count=443
# 這兩張照片概念也太像 6 13
# count=23,like_count=4273,comm_count=449
# 你想要的是大家同理你，現任被砲轟的快感嗎？ 47 13
# count=24,like_count=4286,comm_count=496
# 請你原諒，我有病 2 13
# count=25,like_count=4299,comm_count=498
# 好想死
# 這到底是什麼人生 8 11
# count=26,like_count=4310,comm_count=506
# 不知道該怎麼開口 6 11
# count=27,like_count=4321,comm_count=512
# 想好好睡一覺 2 11
# count=28,like_count=4332,comm_count=514
# 小心台北黃X碩先生 5 11
# count=29,like_count=4343,comm_count=519
# 我的全世界都在崩潰 4 11
# count=30,like_count=4354,comm_count=523
# 熱門平均按讚次數145.1，熱門評論平均次數17.4
#
#
# #新年快樂！研究員來拜年～感謝有你與我們一同見證好物宇宙的誕生🌏 18 345
# count=1,like_count=11,comm_count=4
# 帶骨灰逛夜市…… 23 1885
# count=2,like_count=22,comm_count=8
# 我真的被噁心到了 159 521
# count=3,like_count=33,comm_count=12
# 我有一個護士夢 29 508
# count=4,like_count=44,comm_count=16
# 婚禮伴奏被打槍的後續 18 326
# count=5,like_count=55,comm_count=20
# 差了22歲的弟弟出生啦～～ 18 258
# count=6,like_count=66,comm_count=24
# 媽媽 3 68
# count=7,like_count=77,comm_count=28
# 性騷擾經驗分享 #更 47 43
# count=8,like_count=88,comm_count=32
# 那些侵占仔沒想到的事 8 41
# count=9,like_count=99,comm_count=36
# 社交好累 都在營造自己有朋友的假象 3 38
# count=10,like_count=110,comm_count=40
# 前任夜路走多遇到鬼了：） 17 29
# count=11,like_count=121,comm_count=44
# 放過自己吧 0 24
# count=12,like_count=132,comm_count=48
# 家中有長輩拜託請他們洗澡的時候不要鎖門 4 23
# count=13,like_count=143,comm_count=52
# 我就想微波馬鈴薯啊！ 4 22
# count=14,like_count=154,comm_count=56
# 你這麼忙怎麼還有空___ 2 20
# count=15,like_count=165,comm_count=60
# 引發男女戰爭的事件 62 19
# count=16,like_count=176,comm_count=64
# 臺灣人真溫暖(´；ω；｀) 0 16
# count=17,like_count=187,comm_count=68
# 我媽喜歡把我的事情講出去 4 15
# count=18,like_count=198,comm_count=72
# 是我害死媽媽的... 4 15
# count=19,like_count=209,comm_count=76
# 其實很討厭被摸頭 11 15
# count=20,like_count=220,comm_count=80
# 是我對這個世界有太多期望？ 6 15
# count=21,like_count=231,comm_count=84
# 脾氣好的人都沒底線 3 14
# count=22,like_count=242,comm_count=88
# 這兩張照片概念也太像 6 13
# count=23,like_count=253,comm_count=92
# 你想要的是大家同理你，現任被砲轟的快感嗎？ 47 13
# count=24,like_count=264,comm_count=96
# 請你原諒，我有病 2 13
# count=25,like_count=275,comm_count=100
# 好想死
# 這到底是什麼人生 8 11
# count=26,like_count=286,comm_count=104
# 不知道該怎麼開口 6 11
# count=27,like_count=297,comm_count=108
# 想好好睡一覺 2 11
# count=28,like_count=308,comm_count=112
# 小心台北黃X碩先生 5 11
# count=29,like_count=319,comm_count=116
# 我的全世界都在崩潰 4 11
# count=30,like_count=330,comm_count=120
# 非熱門平均按讚次數11.0，非熱門評論平均次數4.0
